# %% [markdown]
# ### User-Interface System / Program for Manually Computing the Euclidean or Manhattan Distance (City Block Distance) in Two DImensional Space

# %% [markdown]
# ###### Task
# Build a program that enables user choice between computation of the Euclidean Distance or the Manhattan Distance !
#
# Includes:
#
# ###### User-Interface Program
#
# Manually calculating the euclidean/manhattan distance calculations in two dimensional space enabling users to interact with the program.
#
# De - Bugging (Not Included)
#
# This approach involved breaking down the code into small segements for both detetcing bugs and solving tasks required to build this program. This is a good approach for fellow pythonists in developing programs and building skills behind the scenes to succesfully complete such programs.
#
# ###### Project Information
# This program was designed as a subtask of an ongoing project, which is the development of the unsupervised K - Means Clustering Algorithim from scratch !
#
# The rationale for delving into the internals mechanics of the K - Means CLustering Algorithim is simply to gain exposure and experience building algorithims from bottom to top. The aim is to improve & refine skills in python programming which enables such tasks to be succesfully completed to a high standard.
#
# Furthermore this sub-task follows on from previous notebook objectives which manually computed the euclidean distance and manhattan distance of an arbitrary number of elements from two centroid points. The key difference being this program enables user choice between the two metrics mentioned and additionaly includes a scatterplot showing the co-ordinates and centroids which is an interesting feature.
#
# The overall goal of the development of both the euclidean distance & manhattan distance programs is to build a user inter face system enabling user interaction with the K - Means Clustering Algorithim and specifically enabling the user choice between using either the euclidean or manhattan distance metric !
#
#
# ###### Formula's
#
# MANHATAN DISTANCE FORMULA:
#
#                               d([x1,y1],[x2,y2]) => |x2 - x1| + |y2 - y1|
#
# EUCLIDEAN DISTANCE FORMULA:
#
#                               d([x1,y1],[x2,y2]) => sqrt((x1 - x2)**2 + (y1-y2)**2)
#
# NOTE
#
# The aim will be to enter an arbitrary number of centroids and co-ordinates into the program.
#
# Watch out .. scikit learn !

# %%
#import required libraries for program
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from math import sqrt

# %% [markdown]
# ##### Part 1
# User-Interface Program | Part 1
#
# READ & FOLLOW THE BELOW INSTRUCTIONS
#
# Enter the number of elements you wish to caculate the euclidean distace for !
#
# Enter two centroid x & y co ordinates to compute the euclidean distance from the given elements.

# %%
print('Please input the number of elements required :')
n1 = input()
#convert string to integer rationale range function & randinint requires interger value
n1 = int(n1)
print('Please input the max range :')
n2 = input()
n2 = int(n2)

#create two random lists to hold X & Y co - ordinates of elements
#X co-ordinates
X = []
#Y co - ordinates
Y = []

#intialize for loop with the range function (start/end)
for i in range(0,n1):
    #Generates a random number between a given positive range
    x = random.randint(1,n2)
    #appends to empty list(adds)
    X.append(x)
for i in range(0,n1):
    y = random.randint(1,n2)
    Y.append(y)

#Initiate Centroid 1
print('Please enter centroid 1 co - ordinates')
print('Enter x co - ordinate')
cx1 = input()
cx1 = int(cx1)
print('Enter y co - ordinate')
cy1 = input()
cy1 = int(cy1)
print('Centroid 1 x co - ordinates:',cx1)
print('Centroid 1 y co - ordinates:',cy1)

#Initiate Centroid 2
print('Please enter centroid 2 co - ordinates')
print('Enter x co - ordinate')
cx2 = input()
cx2 = int(cx2)
print('Enter y co - ordinate')
cy2 = input()
cy2 = int(cy2)
print('Centroid 2 x co - ordinates:',cx2)
print('Centroid 2 y co - ordinates:',cy2)

#SCATTERPLOT 
#x & y co-ordniates
plt.style.use('ggplot')
fig, ax = plt.subplots()
ax.scatter(X, Y)
# add centroid 1 & centroid 2
plt.scatter(x=[cx1], y=[cy1], color='b')
plt.scatter(x=[cx2], y=[cy2], color='g')
plt.title("X & Y Co-Ordinates | Centroid 1 & 2")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# Please input the number of elements required :
# 200
# Please input the max range :
# 150
# Please enter centroid 1 co - ordinates
# Enter x co - ordinate
# 70
# Enter y co - ordinate
# 90
# Centroid 1 x co - ordinates: 70
# Centroid 1 y co - ordinates: 90
# Please enter centroid 2 co - ordinates
# Enter x co - ordinate
# 110
# Enter y co - ordinate
# 105
# Centroid 2 x co - ordinates: 110
# Centroid 2 y co - ordinates: 105

# %% [markdown]
# #### Part 2
#
# User-Interface Program | Part 2
#
# READ & FOLLOW THE BELOW INSTRUCTIONS
#
# Select which distance metric you wish to use for distance calculation within this two dimensional space.

# %%
#ENABLING USER CHOICE
print('Please Select which distance metric to use for distance calculations')
print('Important Note')
print('SPELLING and CAPITALIZATION must be accurate if not the program will CRASH !')
print('Please Enter one of TWO choices: \
       (1)Euclidean Distance \
       (2)Manhattan Distance')
distance = input()
if distance == 'Euclidean Distance':
    #initiliaze empty lists
    list1 = []
    list2 = []
    list3 = []
    list4 = []
    list5 = []
    list6 = []
    
    #eulcidean distance calculations
    for xi in X:
        #while loop : terminate the for loop when length of list1 exceeds the length of the list2
        while len(X) <= len(X):
            #appending(adding calculations to list)
            list1.append((cx1 - xi) ** 2)
            #appending(adding calculations to list)
            break
    for yi in Y:
        while len(Y) <= len(Y):
            list2.append((cy1 - yi) ** 2)
            break
            
    #for loop to loop over list
    for xii in X:
        while len(X) <= len(X):
            list3.append((cx2 - xii) ** 2)
            break
    for yii in Y:
        while len(Y) <= len(Y):
            list4.append((cy2 - yii) ** 2)
            break
            
    #for loop zipping together two lists   
    for x,y in zip (list1,list2):
        while len(list1) <= len(list2):
            #square root calculations
            phase1 = sqrt(x + y)
            list5.append(phase1)
            break
    for a,b in zip (list3,list4):
        while len(list3) <= len(list4):
            phase2 = sqrt(a + b)
            list6.append(phase2)
            break
    
    print('Euclidean Distance Calculations:',list5)
    #print(type(list5))
    print('Eulclidean Distance Calculations:',list6)
    #print(type(list6))
    
else:
    #Initiate empty list
    list1 = []
    list2 = []
    
    #initiate for loop looping through both lists . zipped .. together in the sequence desired for specific cacluations
    for x,y in zip(X,Y):
        #while loop : iterations continues until list length exceeds the other list length
        while len(X) <= len(Y):
            #append(add) calculations to empty list
            list1.append((cx1 - x) + (cy1 - y))
            #break essential for termination of the iteration process when conditions are met.
            #If not while looped would continue..... its iteration process
            break
    for i,f in zip(X,Y):
        while len(X) <= len(Y):
            list2.append((cx2 - i) + (cy2 - f))
            break
    print('Manhattan Distance | Centroid 1 :', list1)
    print('Manhattan Distance | Centroid 2 :', list2)
# Out:
# Please Select which distance metric to use for distance calculations
# Important Note
# SPELLING and CAPITALIZATION must be accurate if not the program will CRASH !
# Please Enter one of TWO choices:        (1)Euclidean Distance        (2)Manhattan Distance
# Euclidean Distance
# Euclidean Distance Calculations: [84.09518416651456, 67.02984409947557, 101.54801819828883, 32.984845004941285, 75.82216034906945, 76.57675887630658, 33.60059523282288, 83.02409288875127, 55.54277630799526, 72.40165743959182, 56.61271941887264, 68.18357573492314, 33.54101966249684, 60.0, 26.92582403567252, 53.31041174104736, 85.23496934944014, 43.08131845707603, 31.240998703626616, 36.124783736376884, 63.34824385884742, 27.313000567495326, 49.040799340956916, 62.26556030423239, 89.00561780022652, 61.29437168288782, 86.00581375697809, 70.7248188403477, 37